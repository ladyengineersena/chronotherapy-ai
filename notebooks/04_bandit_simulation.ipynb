# %% [markdown]
# # 04: Contextual Bandit Simulation
#
# Simulate personalized treatment timing using contextual bandits (explore-exploit).

# %%
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import json

sys.path.insert(0, str(Path('..')))

from src.models.bandit import LinearUCBBandit
from src.utils import extract_circadian_features
